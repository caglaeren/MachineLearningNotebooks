# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("17-cardekho.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
#Unnamed:0 kolonu csv kaydederken indexi bir daha kaydetmesinden dolayı oluşuyor. Bunu drop ederiz.
df = df.drop("Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15411.000000  1.541100e+04  15411.000000  15411.000000  15411.000000
# mean       6.036338  5.561648e+04     19.701151   1486.057751    100.588254
# std        3.013291  5.161855e+04      4.171265    521.106696     42.972979
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15411.000000   1.541100e+04
# mean       5.325482   7.749711e+05
# std        0.807628   8.941284e+05
# min        0.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.560000e+05
# ...

# %%
df["seats"].value_counts()
# Out:
# seats
# 5    12910
# 7     1922
# 8      311
# 6      127
# 4       77
# 9       55
# 2        7
# 0        2
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#                  car_name       brand        model  vehicle_age  km_driven  \
# 197            Honda City       Honda         City            8      70000
# 360         Maruti Baleno      Maruti       Baleno            2       5000
# 1353   Maruti Swift Dzire      Maruti  Swift Dzire            4      50000
# 1429       Maruti Wagon R      Maruti      Wagon R           13     100000
# 1485          Hyundai i20     Hyundai          i20            3      50000
# ...                   ...         ...          ...          ...        ...
# 15229        Maruti Swift      Maruti        Swift            8      80000
# 15324      Maruti Wagon R      Maruti      Wagon R            6      50000
# 15367          Tata Tiago        Tata        Tiago            4      30000
# 15378       Hyundai Grand     Hyundai        Grand            6      30000
# 15392    Land Rover Rover  Land Rover        Rover            5     128000
#
# ...

# %% [markdown]
# ### Data Cleaning

# %%
#Seats sayısı 0 olan 2 data vardı. Onu seats sayısı 5 olacak şekilde değiştirelim.
#Duplicated olan dataları da drop edelim.

# %%
#keep='first': Aynı olan satırlardan ilkini bırakır diğerini siler.
#ignore_index=True: Duplicate datalar silindikten sonra indexi sıfırdan düzenler. Eski indexi önemsemez.
df = df.drop_duplicates(keep="first", ignore_index=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_name, brand, model, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
df[df['seats'] == 0]
# Out:
#            car_name   brand  model  vehicle_age  km_driven seller_type  \
# 3207     Honda City   Honda   City           18      40000  Individual
# 12504  Nissan Kicks  Nissan  Kicks            2      10000  Individual
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 3207     Petrol            Manual    13.00    1493     100.00      0
# 12504    Diesel            Manual    19.39    1461     108.49      0
#
#        selling_price
# 3207          115000
# 12504        1154000

# %%
df.loc[df['seats'] == 0, "seats"] = 5 #seats değeri 0 olan satırların seats kolonunu 5 yapıyor
#loc koşulu sağlayan satırları/kolonları seçer veya değiştirir.

# %%
df['seats'].value_counts()
# Out:
# seats
# 5    12769
# 7     1902
# 8      310
# 6      125
# 4       76
# 9       55
# 2        7
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15244.000000  1.524400e+04  15244.000000  15244.000000  15244.000000
# mean       6.041131  5.563958e+04     19.697333   1486.171543    100.607652
# std        3.016228  5.176630e+04      4.169307    520.419390     42.915687
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15244.000000   1.524400e+04
# mean       5.326817   7.747014e+05
# std        0.806464   8.946761e+05
# min        2.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.590000e+05
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format) #değiştirmek istediğiniz opsiyonu yazıyorsunuz, ondalıktan sonra kaç sayı geleceği

# %%
df.describe()
# Out:
#        vehicle_age  km_driven  mileage   engine  max_power    seats  \
# count     15244.00   15244.00 15244.00 15244.00   15244.00 15244.00
# mean          6.04   55639.58    19.70  1486.17     100.61     5.33
# std           3.02   51766.30     4.17   520.42      42.92     0.81
# min           0.00     100.00     4.00   793.00      38.40     2.00
# 25%           4.00   30000.00    17.00  1197.00      74.00     5.00
# 50%           6.00   50000.00    19.67  1248.00      88.50     5.00
# 75%           8.00   70000.00    22.70  1582.00     117.30     5.00
# max          29.00 3800000.00    33.54  6592.00     626.00     9.00
#
#        selling_price
# count       15244.00
# mean       774701.45
# std        894676.08
# min         40000.00
# 25%        385000.00
# 50%        559000.00
# 75%        825000.00
# max      39500000.00

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
#Araç yaşına göre satış fiyatı nasıl değişiyor ona bakalım. hue da fuel_type olsun.
sns.scatterplot(x=df['vehicle_age'], y=df['selling_price'], hue=df['fuel_type'])
plt.xlabel('Vehicle Age')
plt.ylabel('Selling Price')
plt.title('Vehicle age-based Selling Price')
plt.show()

# %%
#İki tane çok büyük outlier var ve bu grafiği de bozuyor. Bu outlierları çıkarırsak daha iyi olur.
df['selling_price'].max() #39 milyon 500 binlik araba büyük outlier oluşturuyor. Filtreleme yapacağız
# Out:
# 39500000

# %%
df = df[(df['selling_price'] < 15000000)]

# %%
df.describe()
# Out:
#        vehicle_age  km_driven  mileage   engine  max_power    seats  \
# count     15242.00   15242.00 15242.00 15242.00   15242.00 15242.00
# mean          6.04   55646.31    19.70  1485.68     100.54     5.33
# std           3.02   51766.37     4.17   518.45      42.56     0.81
# min           0.00     100.00     6.00   793.00      38.40     2.00
# 25%           4.00   30000.00    17.00  1197.00      74.00     5.00
# 50%           6.00   50000.00    19.67  1248.00      88.50     5.00
# 75%           8.00   70000.00    22.70  1582.00     117.30     5.00
# max          29.00 3800000.00    33.54  5998.00     626.00     9.00
#
#        selling_price
# count       15242.00
# mean       770623.86
# std        816170.02
# min         40000.00
# 25%        385000.00
# 50%        559000.00
# 75%        825000.00
# max      14500000.00

# %%
#Araç yaşına göre satış fiyatı nasıl değişiyor ona bakalım. hue da fuel_type olsun.
sns.scatterplot(x=df['vehicle_age'], y=df['selling_price'], hue=df['fuel_type'])
plt.xlabel('Vehicle Age')
plt.ylabel('Selling Price')
plt.title('Vehicle age-based Selling Price')
plt.show()

# %%
#Yakıt türüne göre araba satış fiyatı nasıl değişiyor bakalım.
sns.boxplot(data=df, x="fuel_type", y="selling_price")
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.title('Fuel type-based Selling Price')
plt.show() #Petrol ve Dieselde outlierlar gözüküyor.

# %%
#Transmission Type (Şanzıman Türüne) göre satış fiyatı nasıl değişiyor bakalım:
sns.boxplot(data=df, x='transmission_type', y='selling_price')
plt.xlabel('Transmission Type')
plt.ylabel('Selling Price')
plt.title('Transmission type-based Selling Price')
plt.show()

# %%
#kilometreye göre satış fiyatı nasıl değişiyor
sns.scatterplot(data=df, x='km_driven', y='selling_price')
plt.xlabel('KM Driven')
plt.ylabel('Selling Price')
plt.title('KM Driven-based Selling Price')
plt.show()

# %%
df['km_driven'].max()
# Out:
# 3800000

# %%
#Yine filtreleme yapabiliriz bu outlierı kaldırmak için.
df = df[(df['km_driven'] < 1000000)]

# %%
df.describe()
# Out:
#        vehicle_age  km_driven  mileage   engine  max_power    seats  \
# count     15240.00   15240.00 15240.00 15240.00   15240.00 15240.00
# mean          6.04   55317.32    19.70  1485.54     100.53     5.33
# std           3.02   40672.44     4.17   518.31      42.55     0.81
# min           0.00     100.00     6.00   793.00      38.40     2.00
# 25%           4.00   30000.00    17.00  1197.00      74.00     5.00
# 50%           6.00   50000.00    19.67  1248.00      88.50     5.00
# 75%           8.00   70000.00    22.70  1582.00     117.30     5.00
# max          29.00  950000.00    33.54  5998.00     626.00     9.00
#
#        selling_price
# count       15240.00
# mean       770556.03
# std        816201.78
# min         40000.00
# 25%        385000.00
# 50%        558500.00
# 75%        825000.00
# max      14500000.00

# %%
#kilometreye göre satış fiyatı nasıl değişiyor
sns.scatterplot(data=df, x='km_driven', y='selling_price')
plt.xlabel('KM Driven')
plt.ylabel('Selling Price')
plt.title('KM Driven-based Selling Price')
plt.show()

# %%
#Seats (Koltuk sayısına) göre satış fiyatı nasıl değişiyor bakalım:
sns.boxplot(data=df, x='seats', y='selling_price')
plt.xlabel('Seats')
plt.ylabel('Selling Price')
plt.title('Seats-based Selling Price')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                vehicle_age  km_driven  mileage  engine  max_power  seats  \
# vehicle_age           1.00       0.42    -0.26    0.10       0.01   0.03
# km_driven             0.42       1.00    -0.12    0.23       0.05   0.23
# mileage              -0.26      -0.12     1.00   -0.63      -0.53  -0.44
# engine                0.10       0.23    -0.63    1.00       0.81   0.56
# max_power             0.01       0.05    -0.53    0.81       1.00   0.18
# seats                 0.03       0.23    -0.44    0.56       0.18   1.00
# selling_price        -0.26      -0.11    -0.32    0.61       0.77   0.13
#
#                selling_price
# vehicle_age            -0.26
# km_driven              -0.11
# mileage                -0.32
# engine                  0.61
# max_power               0.77
# seats                   0.13
# selling_price           1.00

# %%
#X ve y'yi alalım
X = df.drop('selling_price', axis=1)
y = df['selling_price']

# %%
X.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=15)

# %%
#Data tipi object olan sütunları alır, seçilen sütunların isimlerini index tipinde alır ve python listesine çevirir
cat_cols = df.select_dtypes("object").columns.to_list()

# %%
cat_cols
# Out:
# ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
#Bütün kategorik kolonlar için benzersiz değerleri alalım
unique_values = df[cat_cols].nunique()

# %%
unique_values
# Out:
# car_name             119
# brand                 30
# model                118
# seller_type            3
# fuel_type              5
# transmission_type      2
# dtype: int64

# %% [markdown]
# ### Encoding

# %%
#seller_type, fuel_type ve transmission_type için ->> OneHot Encoding kullanılabilir
#car_name, brand, model ->> Frequency Encoding

# %%
onehot_columns = ['seller_type','fuel_type','transmission_type']
freqhot_columns = ['car_name','brand','model']

# %%
#Frkeans hesaplama:
#car_name sütunundaki her bir kategorinin, Train seti içndeki görülme (frekans) oranı % olarak hesaplanır.
# X_train['car_name'].value_counts() / len(X_train)
# X_train['car_name' + '_freq'] 

#kolonlar için frekans hesaplayalım
for col in freqhot_columns:
    freq = X_train[col].value_counts() / len(X_train)
    #_freq adında yeni bir kolon açtık, bir yanlışlık yaparsak sonra düzeltebilelim diye
    X_train[col + '_freq'] = X_train[col].map(freq)

    X_test[col + '_freq'] = X_test[col].map(freq)
    
    #X_train'de aldığımız bir şey X_test'de yoktu, yapamadık gibi bir durum varsa onu da frekansın ortalaması ile değiştiririz
    mean_freq = freq.mean()
    X_test[col + '_freq'] = X_test[col + '_freq'].fillna(mean_freq)

# %%
X_train.head()
# Out:
#              car_name     brand   model  vehicle_age  km_driven seller_type  \
# 6205  Mahindra XUV500  Mahindra  XUV500            2      18000  Individual
# 7707       Tata Nexon      Tata   Nexon            4      25000  Individual
# 5332  Mahindra XUV500  Mahindra  XUV500            4      58500      Dealer
# 2935      Maruti Eeco    Maruti    Eeco            6      59000      Dealer
# 6419    Maruti Baleno    Maruti  Baleno            4      32000      Dealer
#
#      fuel_type transmission_type  mileage  engine  max_power  seats  \
# 6205    Diesel            Manual    15.10    2179     152.87      7
# 7707    Petrol            Manual    17.00    1198     108.50      5
# 5332    Diesel            Manual    16.00    2179     140.00      7
# 2935    Petrol            Manual    15.10    1196      73.00      7
# 6419    Petrol            Manual    21.01    1197      81.80      5
#
#       car_name_freq  brand_freq  model_freq
# 6205           0.02        0.07        0.02
# ...

# %%
X_test.head()
# Out:
#                car_name       brand     model  vehicle_age  km_driven  \
# 10573       Hyundai i10     Hyundai       i10            7      90000
# 4407      Ford Ecosport        Ford  Ecosport            4      45000
# 5654      Maruti Baleno      Maruti    Baleno            4      71000
# 13787  Volkswagen Vento  Volkswagen     Vento            4      37959
# 1156        Maruti Ciaz      Maruti      Ciaz            2      15260
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 10573      Dealer    Petrol            Manual    19.81    1086      68.05
# 4407   Individual    Diesel            Manual    23.00    1498      98.96
# 5654       Dealer    Diesel            Manual    27.39    1248      74.00
# 13787      Dealer    Petrol         Automatic    18.19    1197     103.20
# 1156       Dealer    Diesel            Manual    28.09    1248      88.50
#
#        seats  car_name_freq  brand_freq  model_freq
# ...

# %%
#Artık car_name, brand ve model kolonlarını drop edebiliriz
X_train = X_train.drop(['car_name', 'model', 'brand'], axis=1)
X_test = X_test.drop(['car_name', 'model', 'brand'], axis=1)

# %%
#OneHot Encoding kısmını yapalım:
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(
    transformers= [
        ("onehot",OneHotEncoder(drop="first", handle_unknown="ignore"),onehot_columns)
    ], remainder="passthrough"
    
)

# %%
X_train = transformer.fit_transform(X_train)
X_test = transformer.transform(X_test)

# %%
encoded_cols = transformer.get_feature_names_out() #ColumnTransformer sonrası oluşan tüm yeni kolon isimlerini verir

# %%
encoded_cols
# Out:
# array(['onehot__seller_type_Individual',
#        'onehot__seller_type_Trustmark Dealer', 'onehot__fuel_type_Diesel',
#        'onehot__fuel_type_Electric', 'onehot__fuel_type_LPG',
#        'onehot__fuel_type_Petrol', 'onehot__transmission_type_Manual',
#        'remainder__vehicle_age', 'remainder__km_driven',
#        'remainder__mileage', 'remainder__engine', 'remainder__max_power',
#        'remainder__seats', 'remainder__car_name_freq',
#        'remainder__brand_freq', 'remainder__model_freq'], dtype=object)

# %%
#X_train ve X_test numpy array olduğu için DF'e çevirelim öyle tutalım
X_train = pd.DataFrame(X_train, columns=encoded_cols)
X_test = pd.DataFrame(X_test, columns=encoded_cols)

# %%
X_train.head()
# Out:
#    onehot__seller_type_Individual  onehot__seller_type_Trustmark Dealer  \
# 0                            1.00                                  0.00
# 1                            1.00                                  0.00
# 2                            0.00                                  0.00
# 3                            0.00                                  0.00
# 4                            0.00                                  0.00
#
#    onehot__fuel_type_Diesel  onehot__fuel_type_Electric  \
# 0                      1.00                        0.00
# 1                      0.00                        0.00
# 2                      1.00                        0.00
# 3                      0.00                        0.00
# 4                      0.00                        0.00
#
#    onehot__fuel_type_LPG  onehot__fuel_type_Petrol  \
# 0                   0.00                      0.00
# 1                   0.00                      1.00
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   onehot__seller_type_Individual        10668 non-null  float64
#  1   onehot__seller_type_Trustmark Dealer  10668 non-null  float64
#  2   onehot__fuel_type_Diesel              10668 non-null  float64
#  3   onehot__fuel_type_Electric            10668 non-null  float64
#  4   onehot__fuel_type_LPG                 10668 non-null  float64
#  5   onehot__fuel_type_Petrol              10668 non-null  float64
#  6   onehot__transmission_type_Manual      10668 non-null  float64
#  7   remainder__vehicle_age                10668 non-null  float64
#  8   remainder__km_driven                  10668 non-null  float64
#  9   remainder__mileage                    10668 non-null  float64
# ...

# %% [markdown]
# ### Modeli Eğitelim

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

# %%
model = AdaBoostRegressor()
model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = model.predict(X_test)

# %%
print("R2 Score:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
print("MSE:", mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.6333568911244357
# MAE: 404067.09218883776
# MSE: 240370487150.01477

# %%
#Hyperparameter Tuning yapalım
params = {
    "n_estimators": [50,80,100,120],
    "learning_rate": [0.001, 0.01, 0.1, 1.0, 2.0],
    "loss": ["linear", "square", "exponential"] #default linear
}

# %%
rcv = RandomizedSearchCV(estimator=AdaBoostRegressor(), param_distributions=params, scoring="r2", cv=5)

# %%
rcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.001, 0.01, 0.1, 1.0,
#                                                           2.0],
#                                         'loss': ['linear', 'square',
#                                                  'exponential'],
#                                         'n_estimators': [50, 80, 100, 120]},
#                    scoring='r2')

# %%
rcv.best_params_
# Out:
# {'n_estimators': 80, 'loss': 'linear', 'learning_rate': 0.01}

# %%
y_pred2 = rcv.predict(X_test)

# %%
print("R2 Score:", r2_score(y_test,y_pred2))
print("MAE:", mean_absolute_error(y_test,y_pred2))
print("MSE:", mean_squared_error(y_test,y_pred2))
# Out:
# R2 Score: 0.7727357524047888
# MAE: 225472.28846697503
# MSE: 148993985114.78006

# %%
#AdaBoostRegressor base estimator olarak DecisionTreeRegressor'ı alır. max_depth=3
params = {
    "estimator__max_depth": [3,4,5],  #default'u 3 
    "n_estimators": [50,80,100,120],
    "learning_rate": [0.001, 0.01, 0.1, 1.0, 2.0],
    "loss": ["linear", "square", "exponential"] #default linear
}

# %%
#AdaBoostRegressor içine estimator alıyor. Bunu vermezsek DecisionTreeRegressor kullanarak initialize eder
# ve DecisionTree içinde de max_depth'i 3 tutar.
rcv = RandomizedSearchCV(estimator=AdaBoostRegressor(DecisionTreeRegressor()), param_distributions=params, scoring="r2", cv=5)

# %%
rcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=AdaBoostRegressor(estimator=DecisionTreeRegressor()),
#                    param_distributions={'estimator__max_depth': [3, 4, 5],
#                                         'learning_rate': [0.001, 0.01, 0.1, 1.0,
#                                                           2.0],
#                                         'loss': ['linear', 'square',
#                                                  'exponential'],
#                                         'n_estimators': [50, 80, 100, 120]},
#                    scoring='r2')

# %%
rcv.best_params_
# Out:
# {'n_estimators': 80,
#  'loss': 'exponential',
#  'learning_rate': 0.1,
#  'estimator__max_depth': 5}

# %%
y_pred3 = rcv.predict(X_test)
print("R2 Score:", r2_score(y_test,y_pred3))
print("MAE:", mean_absolute_error(y_test,y_pred3))
print("MSE:", mean_squared_error(y_test,y_pred3))
# Out:
# R2 Score: 0.8981204060232612
# MAE: 145569.5748872779
# MSE: 66792057567.74702
